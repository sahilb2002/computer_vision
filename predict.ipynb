# %%
from tensorflow import keras
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
model = keras.models.load_model('gender_classification_model')
data = keras.preprocessing.image.ImageDataGenerator()
gen = data.flow_from_directory('predict',target_size=(120,90),color_mode='grayscale',shuffle=False,class_mode=None)
x = gen.next()
files = gen.filepaths

labels = ['Female','Male']
# Out:
# Found 7 images belonging to 1 classes.

# %%
for i,image in enumerate(x):
    img = cv2.imread(files[i])
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    a = np.argmax(model.predict(image.reshape(1,120,90,1)))
    print(labels[a])
    print()
# Out:
# Male
# Female
# Female
# Female
# Female
# Male
# Male

# %%
# image1 = cv2.imread('predict/female/indian.jpeg')
# image1 = image1[0:150,:,:]
# plt.imshow(cv2.cvtColor(image1,cv2.COLOR_BGR2RGB))
# cv2.imwrite('predict/female/female3.jpeg',image1)
